# %% [markdown]
# <a href="https://colab.research.google.com/github/tiberiusjos/json-rpc-work/blob/main/mapReduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
